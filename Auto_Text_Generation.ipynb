# %% [markdown]
# ### **Importing Libraries**

# %%
import pickle
import re
import spacy
import nltk
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from tqdm import tqdm_notebook
import torch
from torch import nn
import torch.nn.functional as F

# %% [markdown]
# ### **Mounting Google derive**

# %%
from google.colab import drive
drive.mount('/content/drive/')

# %%
seed = 2019
torch.manual_seed(seed)

# %% [markdown]
# ### **Loading the Data**

# %%
with open('/content/drive/MyDrive/Dailog-dataset.dialogs_dataset','rb') as f:
 df = pickle.load(f)
df[:10]
# Out:
# ["Hi, I'm looking to book a table for Korean fod",
#  'Somewhere in Southern NYC, maybe the East Village?',
#  " We don't want to sit at the bar, but anywhere else is fine",
#  'What times are available?',
#  "Yikes, we can't do those times",
#  'Let me check',
#  "Great, let's book that",
#  "No, that's it, just book",
#  'Hi I would like to see if the Movie What Men Want is playing here',
#  'Yes, for me and a friend so two tickets please']

# %% [markdown]
# ### **Preparing data**

# %%
type(df)
# Out:
# list

# %%
clean_df = []
for i in df:
  i = re.sub("[^a-zA-Z']"," ",i)
  i = i.lower()
  clean_df.append(i)

# %%
clean_df[:10]
# Out:
# ["hi  i'm looking to book a table for korean fod",
#  'somewhere in southern nyc  maybe the east village ',
#  " we don't want to sit at the bar  but anywhere else is fine",
#  'what times are available ',
#  "yikes  we can't do those times",
#  'let me check',
#  "great  let's book that",
#  "no  that's it  just book",
#  'hi i would like to see if the movie what men want is playing here',
#  'yes  for me and a friend so two tickets please']

# %%
all_text = " ".join(clean_df)
print(clean_df)
# Out:
# ["hi  i'm looking to book a table for korean fod", 'somewhere in southern nyc  maybe the east village ', " we don't want to sit at the bar  but anywhere else is fine", 'what times are available ', "yikes  we can't do those times", 'let me check', "great  let's book that", "no  that's it  just book", 'hi i would like to see if the movie what men want is playing here', 'yes  for me and a friend so two tickets please', 'what time is that moving playing today ', 'what is that about ', 'oh  no can you recommend anything else ', 'well i like movies that are funny', 'well no i like action as well', 'okay can i get two tickets for that  ', 'how much will this cost', 'yes can i bring my own food to theater', 'okay that is fine', 'i want to watch avengers endgame', 'at bangkok close the hotel i a currently staying', "let's watch another movie then", "let's watch how to train your dragon", 'yes  that one', 'so neither choices are playing at the time i want to watch', 'i am no longer interested in watching the movie', 'i want to order a pizza from bertuccis in chelmsford  ma', 'a large please', ' i would like a sporkie pizza', 'no thank you', ' thank you so much', "hi i'd like to order two large pizzas", "i'll have a hawaiian please", "yes  i'd like a large meat lover pizza please", " i'd like a buffalo chicken pizza please", 'hand tossed please', 'also hand tossed please', "no  that's it for today", "it's john doe", "hey chuck  i'd like you to hop online and order me a latte at starbucks", ' can you make a stop there on your way back ', 'the one at the russell invest for me to grab it on my way out', ' let me see', ' i can pick it up before i head into the light rail station', 'no  i really need to cut down the calories', " let's go with a standard cafe latte", 'a tall will be just fine', ' ordered a venti last week and regretted it', " it's four o'clock  i don't need to be that awake", "let's go with the almond", " i've been into that one lately", "no  let's keep it plain", ' i still have the holidays to walk off here', " and chuck  you wanna see a carbon footprint  walk over here and i'll plant one in your backside", "chuck  you're incredibly unhelpful but well intentioned", ' alright  order that thing', ' just use the expense account', 'thank you very much  good sir', ' hey one last thing', 'is that page still open  can you tell me the calorie count on my thing ', "you just had to add that last little detail  didn't you ", 'i would like to order something from bosses pizza can you put in an order for me ', 'i want a small thin crust pizza  with black olives and pepperoni only', 'yes and have them add extra cheese to please', 'thanks so much', 'okay see if you can get any coupons ', "okay that's great is the order under my name ", "that's perfect  thank you so much for your help", "hey  i'm driving and need you to set up an appointment for me at intelligent auto solutions", 'i need to have the brakes changed  oil changed as well as a general tune up done', "well  it's pretty urgent", ' when is the earliest available appointment ', 'oh wow  i really need to have it done today before i leave for my trip tomorrow', 'no  that is too late', 'no  that will be it', ' thanks so much ', 'i want to order a pizza', 'i would like to have a bacon  sausage  and ham pizza with pineapples', 'yes  that sounds great', 'how much is a large pizza ', 'okay  how much is an extra large pizza ', "oh  that's too much", '  how much is a small ', 'that sounds better', " i'd like a small pizza with bacon  sausage  ham and peppers", 'i have my credit card on file that you can charge', 'hi  i need an uber', "i'm going to mission chinese", 'that depends  how much is an uber vs an uber pool ', 'ok  how long will an uber pool take ', "oh  that's too slow i'm running late", ' how long will a regular uber take ', "ok  that's much better", "ok  that's perfect", " can you call the uber  i'll start walking to the pickup location", "no  that's it  thank you", "hey i'd like  ...

# %%
token = all_text.split()
BOW = {}
for word in token:
  if word not in BOW.keys():
    BOW[word] = 1
  else:
    BOW[word] +=1

# %%
word_count = pd.DataFrame({'word':BOW.keys(),'count':BOW.values()})
word_count = word_count.sort_values(by = ['count'])

# %%
word_count.head()
# Out:
#              word  count
# 10949        tabs      1
# 7881       genres      1
# 4217        gakus      1
# 7882   indecisive      1
# 7883      emagine      1

# %%
word_count.tail()
# Out:
#    word  count
# 69  you  11928
# 5     a  13390
# 3    to  14003
# 15  the  15410
# 47    i  19881

# %%
rare_threshold = 3

rare_words = len(word_count[word_count['count'] < rare_threshold]) ## Selecting all the words that appear less than 3 times in whole text as rare words
total_words = len(word_count)

# %%
rare_words_dist = rare_words/total_words*100
rare_words_corpus = word_count[word_count['count'] < rare_threshold]['count'].sum()/word_count['count'].sum()*100

# %%
print('The rare words percentage distribution :',rare_words_dist)
print('The rare words percentage distribution in corpus:',rare_words_corpus)
# Out:
# The rare words percentage distribution : 61.61643835616438
# The rare words percentage distribution in corpus: 1.742686062912748

# %%
rare_words = word_count[word_count['count'] < rare_threshold]['word'].tolist()
rare_words
# Out:
# ['tabs',
#  'genres',
#  'gakus',
#  'indecisive',
#  'emagine',
#  'brissago',
#  "monster's",
#  'idk',
#  'thingy',
#  'lucas',
#  'lt',
#  'maserati',
#  'ghibhi',
#  'heavier',
#  "master's",
#  "marguerita's",
#  'osso',
#  'vogue',
#  "pat's",
#  'creekes',
#  'margueritas',
#  'trained',
#  'westing',
#  'tomaoes',
#  'opposite',
#  'commuting',
#  'measurement',
#  'human',
#  'width',
#  "are't",
#  'cupped',
#  'hawthorn',
#  "grotto's",
#  'revere',
#  'tons',
#  'liam',
#  'nesson',
#  'voice',
#  'chopsticks',
#  'conway',
#  'brisas',
#  'separately',
#  'celica',
#  'ness',
#  'rod',
#  'edison',
#  'ticksts',
#  'shoud',
#  'pice',
#  'upsale',
#  'desribe',
#  'talulas',
#  'hellow',
#  'siroskii',
#  'cottonwood',
#  'plaeas',
#  'whose',
#  'stodgy',
#  'stallion',
#  'westboro',
#  'freind',
#  'violinist',
#  'hireing',
#  'rousemont',
#  'satruday',
#  'ned',
#  'hesperia',
#  'threw',
#  'honds',
#  "toyota's",
#  'admit',
#  'trail',
#  'army',
#  'hammerhead',
#  'intantly',
#  'eachtoher',
#  'layout',
#  "kobe's",
#  'bonanzo',
#  'beasts',
#  'crimes',
#  'grindelwald',
#  'gaslamp',
#  'windsor',
#  'mallard',
#  'walleye',
#  'goodyear',
#  'victorian',
#  "jansen's",
#  'funky',
#  'blk',
#  'knapp',
#  'amazonas',
#  'premeire',
#  'bijou',
#  'shojis',
#  'watertown',
#  "oh's",
#  'tami',
#  'rancheros',
#  'axles',
#  'chinatown',
#  'melazane',
#  'cattleman',
#  'minor',
#  'regina',
#  'craeft',
#  'urbana',
#  'drifts',
#  'pouring',
#  'ppr',
#  'afreaid',
#  'models',
#  'dispatched',
#  'stays',
#  'vee',
#  'hy',
#  'hesitate',
#  'bussiness',
#  'reboot',
#  'delicios',
#  'stoping',
#  'niles',
#  'peeps',
#  "vinny's",
#  'inexpensive',
#  'mildly',
#  'reveived',
#  'voucher',
#  'dogs',
#  'restarting',
#  'peppemint',
#  'gardena',
#  'stine',
#  'advanced',
#  'whack',
#  'aide',
#  'captions',
#  'reef',
#  'southdale',
#  'musician',
#  'cancelation',
#  'economy',
#  'dg',
#  'emoji',
#  'smiley',
#  'hydration',
#  'somebody',
#  'mangos',
#  "lucille's",
#  'dinning',
#  "sizzler's",
#  'crumble',
#  'carrying',
#  'capacities',
#  'imperial',
#  'harshly',
#  'varity',
#  'spirits',
#  'android',
#  'astro',
#  'degree',
#  'wedges',
#  'julian',
#  'parmeasan',
#  'maharaja',
#  'pinnacle',
#  'frappucinno',
#  'edition',
#  'arms',
#  'attleboro',
#  'alvyn',
#  'irrelevant',
#  'formation',
#  'grom',
#  'hankering',
#  'effective',
#  'candlelit',
#  'selecting',
#  'adapt',
#  'minivans',
#  'society',
#  'blast',
#  'killer',
#  'lecture',
#  'maze',
#  'cafee',
#  'learning',
#  'tropical',
#  "papasito's",
#  'worker',
#  'cucos',
#  'pushes',
#  'imported',
#  'riesling',
#  'blanc',
#  'sauvignon',
#  'rambling',
#  'bellagios',
#  'cyborg',
#  'vineyard',
#  'ful',
#  'stagioni',
#  'berttuccis',
#  'odrer',
#  'mornig',
#  'caffichino',
#  'ordere',
#  'ame',
#  'gervasi',
#  'credic',
#  'smalls',
#  'appoiment',
#  'fumes',
#  "ferg's",
#  'tropicana',
#  'psu',
#  'corperate',
#  'understanding',
#  'apoinment',
#  'ian',
#  'tickers',
#  'stray',
#  'waive',
#  'stripped',
#  'harmed',
#  'carnell',
#  'wailea',
#  'okc',
#  'cox',
#  'kamaole',
#  'circumstances',
#  'solano',
#  'bencotto',
#  "greg's",
#  'clearfield',
#  'byee',
#  'lindsey',
#  'sighted',
#  'frapacino',
#  'anthing',
#  'condos',
#  'error',
#  'sweeteners',
#  'baker',
#  'discussions',
#  'arrow',
#  'race',
#  'benefit',
#  'relationship',
#  'souffl',
#  'pricings',
#  'aobut',
#  'graduates',
#  'talent',
#  'ant',
#  'attractions',
#  'capt',
#  'results',
#  'shareholder',
#  'pigs',
#  'junkiez',
#  'caretta',
#  'youtatiana',
#  'quattro',
#  'prperly',
#  'ramos',
#  'rendition',
#  'kayne',
#  'shakira',
#  'rotor',
#  'fax',
#  'gouging',
#  'acquarium',
#  'net',
#  'sherin',
#  'brochures',
#  'weathervanes',
#  'safer',
#  "cardinal's",
#  'heist',
#  'pagosa',
#  'gwendolyn',
#  'motzerella',
#  'chees',
#  'purgacito',
#  "gordman's",
#  'salvadorian',
#  "commissioner's",
#  'reasons',
#  'rabbit',
#  'luckily',
#  'keystone',
#  'prove',
#  'grounds',
#  'uberluxsuv',
#  'ridehsare',
#  'belinda',
#  'awsome',
#  'nhl',
#  'wealthy',
#  'tc',
#  'availablity',
#  'ballgame',
#  "sara's",
#  'jj',
#  'lydia',
#  'bayside',
#  'straigh',
#  'impacting',
#  'electronics',
#  'electonic',
#  'cock',
#  "scotti's",
#  'chikin',
#  'leap',
#  "stag's",
#  'cakebread',
#  'rented',
#  'signage',
#  'bull',
#  'castleton',
#  'compromised',
#  'rofl',
#  'pushing',
#  'gods',
#  "cafora's",
#  'smiled',
#  'portsmouth',
#  'korger',
#  'quincy',
#  'mainstrasse',
#  'dufus',
#  'rarely',
#  'muh',
#  'knoxville',
#  'saline',
#  'systems',
#  'receiving',
#  'eden',
#  'carbone',
#  'driskill',
#  'gget',
#  'fnacy',
#  "needn't",
#  'saturn',
#  'tori',
#  'evergree',
#  'coversation',
#  'dickinson',
#  'wynn',
#  'reeady',
#  'outlet',
#  'motobike',
#  'vincent',
#  'batteries',
#  'milliken',
#  'patronize',
#  'agitated',
#  'meh',
#  'lie',
#  'billing',
#  'virtual',
#  'hurtful',
#  'calda',
#  'rochelle',
#  "d'arcys",
#  'ver',
#  'fulfill',
#  'guerneville',
#  "george's",
#  'flood',
#  'businesses',
#  'rainy',
#  'sweeten',
#  'scheels',
#  'misfiring',
#  'knees',
#  'promise',
#  'november',
#  'chen',
#  'goodmorning',
#  'skokie',
#  'killens',
#  'rare',
#  'sterring',
#  'oi',
#  'biga',
#  'funnel',
#  'eith',
#  'stapleton',
#  'bored',
#  'limburg',
#  'denny',
#  'zekes',
#  'mariners',
#  "bee's",
#  'aooner',
#  'suzi',
#  "you'r",
#  'screams',
#  'teavana',
#  'overflow',
#  'premiere',
#  'crv',
#  'wobbling',
#  'frapuccino',
#  'consolidated',
#  'dollywood',
#  'coleman',
#  'sugarlands',
#  'candelight',
#  'veering',
#  'bpr',
#  'extended',
#  "life's",
#  'survive',
#  'pepperone',
#  'ballast',
#  'drivethrough',
#  'disappears',
#  'maxima',
#  'emergany',
#  'vending',
#  'considered',
#  'domios',
#  'infusion',
#  'pronounce',
#  'shaken',
#  'embrace',
#  'giannis',
#  'assistants',
#  'uncultured',
#  'swine',
#  'duh',
#  'nominee',
#  'embarrassing',
#  'costume',
#  'introducing',
#  'relly',
#  'uhhhhh',
#  'president',
#  'spghetti',
#  'chcolate',
#  'tuscan',
#  'story',
#  'momoa',
#  'villager',
#  'mercury',
#  'tailpipe',
#  'noticing',
#  'sensation',
#  'poppyseed',
#  'shoots',
#  'clunk',
#  'geesh',
#  'mochafrom',
#  'treasury',
#  'pavilions',
#  'perk',
#  'vegatables',
#  'crest',
#  'finest',
#  'lima',
#  'andrea',
#  'awang',
#  'murasaki',
#  'honking',
#  'moline',
#  'jonnies',
#  'munchies',
#  'haze',
#  'playful',
#  'xyz',
#  'lands',
#  'airports',
#  'clearest',
#  'containing',
#  'elmira',
#  'pastrami',
#  'chartreuse',
#  'munchie',
#  'doubt',
#  'diabetic',
#  'mimosas',
#  'stonewalls',
#  "wegman's",
#  'indonesian',
#  'pancheros',
#  'spread',
#  'bahama',
#  'uni',
#  'cookeville',
#  "carmelina's",
#  "nobody's",
#  'queasy',
#  'tippy',
#  'toluca',
#  'oolong',
#  'gaspers',
#  'ybor',
#  'arrage',
#  'hellob',
#  'wilkshire',
#  'ua',
#  'brillo',
#  'yaris',
#  'thosuand',
#  'hardrock',
#  'jasmine',
#  'parmesean',
#  'viet',
#  "it'",
#  'fender',
#  'fourty',
#  'immediate',
#  'hotdogs',
#  'wet',
#  'mias',
#  'redemption',
#  'caviar',
#  'retain',
#  'mexico',
#  'triangle',
#  'woman',
#  'benjamin',
#  'merlin',
#  'mcwillow',
#  'soups',
#  'rapidly',
#  'rewatching',
#  'armargosa',
#  'exra',
#  'awanas',
#  'drizzel',
#  'bowel',
#  'busters',
#  'mccall',
#  'sizzle',
#  'eastside',
#  'hah',
#  'forcing',
#  'elaina',
#  'contacting',
#  "napoli's",
#  "o'",
#  'stix',
#  "its'",
#  'dubuque',
#  'funghi',
#  'carciofi',
#  'napoletano',
#  'delfina',
#  'mcdonough',
#  'edora',
#  'arches',
#  'hartfield',
#  'appetizer',
#  'pikeville',
#  'blackkklansman',
#  'mirage',
#  'gunbarrel',
#  'wilcox',
#  'railroad',
#  'tennessee',
#  'olas',
#  "savini's",
#  'monk',
#  'victors',
#  "victor's",
#  'goint',
#  'jacked',
#  'mastcard',
#  'reference',
#  'needful',
#  'latour',
#  'rink',
#  'skating',
#  'collins',
#  'refills',
#  'jurrasic',
#  "charles'",
#  'comped',
#  'hosted',
#  'disable',
#  'routing',
#  'beauty',
#  'temples',
#  'essex',
#  'daiya',
#  'peaks',
#  'felix',
#  'sanity',
#  'cinnmon',
#  'ratio',
#  'tapped',
#  'upsetting',
#  'newnan',
#  'thomas',
#  'rhett',
#  "craig's",
#  'csu',
#  'situations',
#  'racket',
#  'packed',
#  'referees',
#  'authorization',
#  'dumb',
#  'ubur',
#  'kelgren',
#  'spinasse',
#  'liner',
#  'redone',
#  'kellogg',
#  'cinnabon',
#  'tofu',
#  'splends',
#  'stack',
#  'fuss',
#  'takata',
#  'cattlemans',
#  "sambino's",
#  'eel',
#  'loyalty',
#  'additionally',
#  "beto's",
#  'rumble',
#  "mancy's",
#  'expenisve',
#  'shell',
#  'spotlight',
#  "darrow's",
#  'enchiladas',
#  'apparently',
#  'tsukiji',
#  'scrubbing',
#  'nothng',
#  'align',
#  "let'",
#  'skittles',
#  'altamonte',
#  'shaw',
#  'strabucks',
#  'anchorage',
#  'loyola',
#  'fetched',
#  'choclate',
#  'frappuchinos',
#  'timer',
#  'scolar',
#  'prixe',
#  'calamari',
#  'compensate',
#  'tamarindo',
#  'morel',
#  'caliber',
#  'emmanuel',
#  "appointment's",
#  'drenched',
#  'corpus',
#  'sweaty',
#  'christi',
#  'stutters',
#  'submitt',
#  'dedicated',
#  'bidwell',
#  'espresoo',
#  'tusk',
#  'servicer',
#  'breaker',
#  'folds',
#  'hu',
#  'mexicano',
#  'lawrenceburg',
#  'reminded',
#  'mabry',
#  'confim',
#  'cited',
#  'debiting',
#  'billings',
#  'yesh',
#  'perkins',
#  'gates',
#  'pin',
#  'admiral',
#  'kamado',
#  'cher',
#  'unusually',
#  "jane's",
#  'bloomingdale',
#  "andy's",
#  'colony',
#  'meijer',
#  'substitiute',
#  'complementary',
#  'hiya',
#  'pretzels',
#  'afloat',
#  'nadine',
#  'figueroa',
#  'caused',
#  'theouh',
#  'shooken',
#  'strunk',
#  "companie's",
#  'frazzled',
#  'cuz',
#  'frills',
#  'youve',
#  'damages',
#  'wiz',
#  'managers',
#  'fed',
#  "nashville's",
#  'mack',
#  'modesto',
#  'delancey',
#  "'s",
#  "allesandro's",
#  'dive',
#  'dobson',
#  'hon',
#  'fans',
#  'oscars',
#  'sephora',
#  'powell',
#  'ping',
#  "annabelle's",
#  'suze',
#  'sketchy',
#  'nwa',
#  'adjusting',
#  'nugget',
#  'carburetor',
#  'sarasota',
#  'towing',
#  'milano',
#  'kokomo',
#  'mccarran',
#  "tiago's",
#  'rt',
#  'olivies',
#  'tabitha',
#  'assembly',
#  'application',
#  'rustic',
#  "'",
#  "amy's",
#  'olde',
#  'uberlux',
#  "sinbad's",
#  'caravans',
#  'kabob',
#  'niagra',
#  'abercorn',
#  'vocal',
#  'riverwalk',
#  'hig',
#  'previously',
#  'jalaplarge',
#  'pizzaeno',
#  'gastonia',
#  'winchells',
#  'seaquest',
#  'halzenut',
#  'printer',
#  'psi',
#  'knot',
#  'notified',
#  'bayou',
#  'fractured',
#  'carefully',
#  'cramp',
#  'angle',
#  'browns',
#  'henrico',
#  'database',
#  'speakers',
#  'cody',
#  'selma',
#  "angi's",
#  'angis',
#  'ironwood',
#  'prepurchase',
#  'blasphemy',
#  'eubank',
#  'goa',
#  'bench',
#  'candado',
#  'signals',
#  'appropriately',
#  'mortons',
#  "senior's",
#  "joyce's",
#  'availablele',
#  'joyce',
#  'occc',
#  'thou',
#  'aye',
#  'umbrella',
#  'sponsor',
#  "mckinnen's",
#  'potential',
#  "palermo's",
#  'lawn',
#  'agostinos',
#  'jacimos',
#  'macchato',
#  'pigeon',
#  'elgin',
#  'sutton',
#  'olathe',
#  'pomodori',
#  'mocchiato',
#  'smokers',
#  'neccesary',
#  'seatac',
#  'hussan',
#  'garfield',
#  'seminar',
#  'choprah',
#  'indy',
#  'gang',
#  'sterling',
#  'risle',
#  'doughroom',
#  'slc',
#  'diagnosed',
#  'fanta',
#  'solutionss',
#  'completes',
#  'precice',
#  'lenna',
#  'imaginative',
#  'jamestown',
#  'nutrition',
#  'chautauqua',
#  'institution',
#  'xes',
#  'notte',
#  'prep',
#  'cheesey',
#  'ninja',
#  'athenaeum',
#  'wiped',
#  'pathfinder',
#  "something's",
#  'winters',
#  'manufacture',
#  "frank's",
#  'resturaunt',
#  'column',
#  'aim',
#  'bluebonnet',
#  'repetitive',
#  'thre',
#  'english',
#  'hooking',
#  'evans',
#  "law's",
#  'conover',
#  'continental',
#  'northeast',
#  'remain',
#  'shutter',
#  'ect',
#  'chesse',
#  'becase',
#  'penne',
#  'audible',
#  'windsheld',
#  'neighbourhood',
#  'semi',
#  'chedule',
#  'ulti',
#  'centry',
#  'katella',
#  'pity',
#  'hippie',
#  'position',
#  'youable',
#  'pleaes',
#  'attendees',
#  'hd',
#  'replies',
#  'recomend',
#  'pairing',
#  'merlot',
#  'lookign',
#  'teen',
#  'racing',
#  "virgil's",
#  'fgo',
#  'anteatery',
#  'natomas',
#  'autonomus',
#  'arguing',
#  'resorts',
#  'thanls',
#  'soya',
#  'june',
#  "fiori's",
#  'weapon',
#  'snub',
#  'potomac',
#  'luger',
#  'rifles',
#  'threat',
#  'claire',
#  'convertible',
#  'bedford',
#  'atm',
#  'conseco',
#  'dover',
#  'waltmart',
#  "toddler's",
#  'bandidos',
#  'dos',
#  'opt',
#  'mainstream',
#  'jolene',
#  'crunchier',
#  'carlisle',
#  'addison',
#  'lynchburg',
#  'navigate',
#  'unintuitive',
#  'lambodari',
#  "knott's",
#  'assis',
#  'provides',
#  'beefs',
#  'tvs',
#  'roadster',
#  'broadmoor',
#  "d'",
#  'toronto',
#  'poke',
#  'fig',
#  'shaded',
#  'rsvp',
#  'rhe',
#  'clubs',
#  'mayfaire',
#  'wander',
#  'ccarr',
#  'term',
#  'wanda',
#  'screamin',
#  "duke's",
#  'bulls',
#  "bull's",
#  'banchie',
#  'suprize',
#  'whitefish',
#  'nas',
#  'gaspares',
#  "oliver's",
#  "abigail's",
#  'ported',
#  'ashlan',
#  'equally',
#  'bridgetown',
#  'tye',
#  'dye',
#  'dust',
#  'moss',
#  'entering',
#  'geeze',
#  'smh',
#  'godzilla',
#  'brady',
#  'samosa',
#  'tomoatoes',
#  'mondo',
#  'braveheart',
#  'eola',
#  'fifty',
#  'tamarack',
#  'emeryville',
#  'waaayyyy',
#  'blessings',
#  'struggles',
#  'appreicate',
#  'existing',
#  'federal',
#  'universtiy',
#  'samurai',
#  'amber',
#  'speer',
#  'tanque',
#  'metropolitan',
#  'inlaws',
#  "vita's",
#  'kitsap',
#  'kettle',
#  'foundu',
#  "cinco's",
#  'overkill',
#  'wrapping',
#  ...]

# %%
data = []                                 
for sents in tqdm_notebook(clean_df):
  for word in sents:                           # Removing the rare words with unknown token in text
    if word in rare_words:
      sent = re.sub(word,'<unk>',sents)
      data.append(sent)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:2: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
# HBox(children=(FloatProgress(value=0.0, max=64776.0), HTML(value='')))

# %%
data[:10]
# Out:
# ['hi  i<unk>m looking to book a table for korean fod',
#  ' we don<unk>t want to sit at the bar  but anywhere else is fine',
#  'yikes  we can<unk>t do those times',
#  'great  let<unk>s book that',
#  'no  that<unk>s it  just book',
#  'let<unk>s watch another movie then',
#  'let<unk>s watch how to train your dragon',
#  'i want to order a pi<unk><unk>a from bertuccis in chelmsford  ma',
#  'i want to order a pi<unk><unk>a from bertuccis in chelmsford  ma',
#  ' i would like a sporkie pi<unk><unk>a']

# %%
len(token)
# Out:
# 477137

# %%
# capture length of all the sequences

text_word_count = []
for i in data:
  text_word_count.append(len(i.split()))

# %%
pd.Series(text_word_count).hist(bins = 30,range = (0,30))

# %%
def create_seq(text,seq_len = 8):           # Choose sequence length 8 as most of the sentence in text are of less than 10 

  sequences = []

  if len(text.split()) > seq_len:
    for i in range(seq_len,len(text.split())):
      seq = text.split()[i-seq_len:i+1]
      sequences.append(" ".join(seq))
    return sequences

  else:
    return [text]

# %%
seqs = [create_seq(i) for i in data]

# %%
seqs[:15]
# Out:
# [['hi i<unk>m looking to book a table for korean',
#   'i<unk>m looking to book a table for korean fod'],
#  ['we don<unk>t want to sit at the bar but',
#   'don<unk>t want to sit at the bar but anywhere',
#   'want to sit at the bar but anywhere else',
#   'to sit at the bar but anywhere else is',
#   'sit at the bar but anywhere else is fine'],
#  ['yikes  we can<unk>t do those times'],
#  ['great  let<unk>s book that'],
#  ['no  that<unk>s it  just book'],
#  ['let<unk>s watch another movie then'],
#  ['let<unk>s watch how to train your dragon'],
#  ['i want to order a pi<unk><unk>a from bertuccis in',
#   'want to order a pi<unk><unk>a from bertuccis in chelmsford',
#   'to order a pi<unk><unk>a from bertuccis in chelmsford ma'],
#  ['i want to order a pi<unk><unk>a from bertuccis in',
#   'want to order a pi<unk><unk>a from bertuccis in chelmsford',
#   'to order a pi<unk><unk>a from bertuccis in chelmsford ma'],
#  [' i would like a sporkie pi<unk><unk>a'],
#  [' i would like a sporkie pi<unk><unk>a'],
#  ['hi i<unk>d like to order two large pizzas'],
#  ["hi i'd like to order two large pi<unk><unk>as"],
#  ["hi i'd like to order two large pi<unk><unk>as"],
#  ['i<unk>ll have a hawaiian please']]

# %%
seqs = sum(seqs,[])

# %%
seqs[:15]
# Out:
# ['hi i<unk>m looking to book a table for korean',
#  'i<unk>m looking to book a table for korean fod',
#  'we don<unk>t want to sit at the bar but',
#  'don<unk>t want to sit at the bar but anywhere',
#  'want to sit at the bar but anywhere else',
#  'to sit at the bar but anywhere else is',
#  'sit at the bar but anywhere else is fine',
#  'yikes  we can<unk>t do those times',
#  'great  let<unk>s book that',
#  'no  that<unk>s it  just book',
#  'let<unk>s watch another movie then',
#  'let<unk>s watch how to train your dragon',
#  'i want to order a pi<unk><unk>a from bertuccis in',
#  'want to order a pi<unk><unk>a from bertuccis in chelmsford',
#  'to order a pi<unk><unk>a from bertuccis in chelmsford ma']

# %%
len(seqs)
# Out:
# 67993

# %%
x = []
y = []

for i in seqs:
  x.append(" ".join(i.split()[:-1]))
  y.append(" ".join(i.split()[1:]))

# %%
x[0]  , y[0]
# Out:
# ('hi i<unk>m looking to book a table for',
#  'i<unk>m looking to book a table for korean')

# %%
int2token = {}                              # Giving each token or word in text a unique interger name which help in converting text into integer
cnt = 1

for w in set(" ".join(data).split()):
  int2token[cnt] = w
  cnt +=1

token2int = {t:i for i,t in int2token.items()}

# %%
token2int['can']
# Out:
# 929

# %%
int2token[5181]
# Out:
# 'nv'

# %%
x_tr = x[:50000]
y_tr = y[:50000]

x_val = x[50000:]
y_val = y[50000:]

# %%
# plot sequence length in train set
text_word_count = []

for i in x_tr:
  text_word_count.append(len(i.split()))

pd.Series(text_word_count).hist(bins = 70,range=(0,30))

# %%
max_text_len = 8                           # Padding the sequence to make it of equal length

def pad_sequence(seq,n):
  seq = seq.split()

  if len(seq) < 8:
    for i in range(n-len(seq)):
      seq.append('<pad>')

  return " ".join(seq)

# %%
x_tr_padded = [pad_sequence(s,max_text_len) for s in x_tr]
y_tr_padded = [pad_sequence(s,max_text_len) for s in y_tr]

x_val_padded = [pad_sequence(s,max_text_len) for s in x_val]
y_val_padded = [pad_sequence(s,max_text_len) for s in y_val]

# %%
x_tr_padded[:20]
# Out:
# ['hi i<unk>m looking to book a table for',
#  'i<unk>m looking to book a table for korean',
#  'we don<unk>t want to sit at the bar',
#  'don<unk>t want to sit at the bar but',
#  'want to sit at the bar but anywhere',
#  'to sit at the bar but anywhere else',
#  'sit at the bar but anywhere else is',
#  'yikes we can<unk>t do those <pad> <pad> <pad>',
#  'great let<unk>s book <pad> <pad> <pad> <pad> <pad>',
#  'no that<unk>s it just <pad> <pad> <pad> <pad>',
#  'let<unk>s watch another movie <pad> <pad> <pad> <pad>',
#  'let<unk>s watch how to train your <pad> <pad>',
#  'i want to order a pi<unk><unk>a from bertuccis',
#  'want to order a pi<unk><unk>a from bertuccis in',
#  'to order a pi<unk><unk>a from bertuccis in chelmsford',
#  'i want to order a pi<unk><unk>a from bertuccis',
#  'want to order a pi<unk><unk>a from bertuccis in',
#  'to order a pi<unk><unk>a from bertuccis in chelmsford',
#  'i would like a sporkie <pad> <pad> <pad>',
#  'i would like a sporkie <pad> <pad> <pad>']

# %%
y_tr_padded[:20]
# Out:
# ['i<unk>m looking to book a table for korean',
#  'looking to book a table for korean fod',
#  'don<unk>t want to sit at the bar but',
#  'want to sit at the bar but anywhere',
#  'to sit at the bar but anywhere else',
#  'sit at the bar but anywhere else is',
#  'at the bar but anywhere else is fine',
#  'we can<unk>t do those times <pad> <pad> <pad>',
#  'let<unk>s book that <pad> <pad> <pad> <pad> <pad>',
#  'that<unk>s it just book <pad> <pad> <pad> <pad>',
#  'watch another movie then <pad> <pad> <pad> <pad>',
#  'watch how to train your dragon <pad> <pad>',
#  'want to order a pi<unk><unk>a from bertuccis in',
#  'to order a pi<unk><unk>a from bertuccis in chelmsford',
#  'order a pi<unk><unk>a from bertuccis in chelmsford ma',
#  'want to order a pi<unk><unk>a from bertuccis in',
#  'to order a pi<unk><unk>a from bertuccis in chelmsford',
#  'order a pi<unk><unk>a from bertuccis in chelmsford ma',
#  'would like a sporkie pi<unk><unk>a <pad> <pad> <pad>',
#  'would like a sporkie pi<unk><unk>a <pad> <pad> <pad>']

# %%
int2token[0] = '<pad>'
token2int['<pad>'] = 0

# %%
vocab_size = len(int2token)

# %%
vocab_size
# Out:
# 6775

# %%
def get_integer_seq(seq):
  return[token2int[w] for w in seq.split()]

# %%
# convert text sequences to integer sequences
x_tr_int = [get_integer_seq(i) for i in x_tr_padded]
y_tr_int = [get_integer_seq(i) for i in y_tr_padded]

x_val_int = [get_integer_seq(i) for i in x_val_padded]
y_val_int = [get_integer_seq(i) for i in y_val_padded]

# %%
x_tr_int[:10]
# Out:
# [[2882, 1650, 5103, 2823, 4653, 415, 3150, 3542],
#  [1650, 5103, 2823, 4653, 415, 3150, 3542, 4179],
#  [712, 398, 5382, 2823, 3741, 853, 3562, 6711],
#  [398, 5382, 2823, 3741, 853, 3562, 6711, 5042],
#  [5382, 2823, 3741, 853, 3562, 6711, 5042, 94],
#  [2823, 3741, 853, 3562, 6711, 5042, 94, 552],
#  [3741, 853, 3562, 6711, 5042, 94, 552, 3979],
#  [1114, 712, 5201, 3151, 5658, 0, 0, 0],
#  [6391, 3862, 4653, 0, 0, 0, 0, 0],
#  [1609, 5234, 5002, 6544, 0, 0, 0, 0]]

# %%
y_tr_int[:10]
# Out:
# [[1650, 5103, 2823, 4653, 415, 3150, 3542, 4179],
#  [5103, 2823, 4653, 415, 3150, 3542, 4179, 2677],
#  [398, 5382, 2823, 3741, 853, 3562, 6711, 5042],
#  [5382, 2823, 3741, 853, 3562, 6711, 5042, 94],
#  [2823, 3741, 853, 3562, 6711, 5042, 94, 552],
#  [3741, 853, 3562, 6711, 5042, 94, 552, 3979],
#  [853, 3562, 6711, 5042, 94, 552, 3979, 2166],
#  [712, 5201, 3151, 5658, 2865, 0, 0, 0],
#  [3862, 4653, 3274, 0, 0, 0, 0, 0],
#  [5234, 5002, 6544, 4653, 0, 0, 0, 0]]

# %%
x_tr_int = np.array(x_tr_int)                     # converting data into array
y_tr_int = np.array(y_tr_int)

x_val_int = np.array(x_val_int)
y_val_int = np.array(y_val_int)

# %%
x_tr_int.shape ,y_tr_int.shape ,x_val_int.shape , y_val_int.shape
# Out:
# ((50000, 8), (50000, 8), (17993, 8), (17993, 8))

# %%
# define model architecture

## embedding layer: 
##    input dim = vocab_size, 
##    ouput dim = 200

## LSTM layer:
##    input dim = 200
##    hidden units = 256
##    layers = 2
##    output dim = 256

## Dropout Layer
##    input dim = 256
##    output dim = 256

## fully connected layer
##    input dim = 256
##    ouput dim = vocab_size

class WordLSTM(nn.Module):
      
  def __init__(self, n_hidden=256, n_layers=2, drop_prob=0.3, lr=0.001):
    super().__init__()
    self.drop_prob = drop_prob
    self.n_layers = n_layers
    self.n_hidden = n_hidden
    self.lr = lr
    
    self.emb_layer = nn.Embedding(vocab_size, 200)

    ## define the LSTM
    # input data is of shape (batch size, sequence length, no. of features)...
    # ...therefore we need batch_first=True
    self.lstm = nn.LSTM(200, n_hidden, n_layers, batch_first=True)
    
    ## define a dropout layer
    self.dropout = nn.Dropout(drop_prob)
    
    ## define the fully-connected layer
    self.fc = nn.Linear(n_hidden, vocab_size)      
  
  def forward(self, x, hidden):
    ''' Forward pass through the network. 
        These inputs are x, and the hidden/cell state is `hidden`. '''

    ## pass input through embedding layer
    embedded = self.emb_layer(x)     
    
    ## Get the outputs and the new hidden state from the lstm
    lstm_output, hidden = self.lstm(embedded, hidden)
    
    ## pass through a dropout layer
    out = self.dropout(lstm_output)
    
    ## reshape the tensor to the shape (batch-size*sequence length, hidden units)
    out = out.reshape(-1, self.n_hidden)

    ## put "out" through the fully-connected layer
    out = self.fc(out)

    # return the final output and the hidden state
    return out, hidden
    
    
  def init_hidden(self, batch_size):
    ''' Initializes hidden state '''
    # Create two new tensors with sizes n_layers x batch_size x n_hidden,
    # initialized to zero, for hidden state and cell state of LSTM
    weight = next(self.parameters()).data

    if (torch.cuda.is_available()):
      hidden = (weight.new(self.n_layers, batch_size, self.n_hidden).zero_().cuda(),
                weight.new(self.n_layers, batch_size, self.n_hidden).zero_().cuda())
    else:
      hidden = (weight.new(self.n_layers, batch_size, self.n_hidden).zero_(),
                weight.new(self.n_layers, batch_size, self.n_hidden).zero_())
    
    return hidden

# %%
net = WordLSTM()
print(net)
# Out:
# WordLSTM(
#   (emb_layer): Embedding(6775, 200)
#   (lstm): LSTM(200, 256, num_layers=2, batch_first=True)
#   (dropout): Dropout(p=0.3, inplace=False)
#   (fc): Linear(in_features=256, out_features=6775, bias=True)
# )

# %%
# function to generate batches
def get_batches(arr_x, arr_y, batch_size):
  # iterate through the arrays
  prv = 0
  
  for n in range(batch_size, arr_x.shape[0], batch_size):
    # batch of input sequences
    x = arr_x[prv:n,:]

    # batch of target sequences
    y = arr_y[prv:n,:]

    prv = n
    
    yield x, y

# %%
def train(net, epochs=10, batch_size=32, lr=0.001, print_every=32):
      
  # set initial loss to infinite
  best_valid_loss = float('inf')
  
  # optimizer
  opt = torch.optim.Adam(net.parameters(), lr=lr)
  
  # loss function
  criterion = nn.CrossEntropyLoss()
  
  if(torch.cuda.is_available()):
    # push model to GPU
    net.cuda()
  
  counter = 0

  net.train()

  for e in range(epochs):
            

    # iterate over batches
    for x, y in get_batches(x_tr_int, y_tr_int, batch_size):
      counter+= 1
      
      # convert arrays to tensors
      inputs, targets = torch.from_numpy(x), torch.from_numpy(y)
      
      if(torch.cuda.is_available()):
        # push tensors to GPU
        inputs, targets = inputs.cuda(), targets.cuda()

      # initialize hidden state
      h = net.init_hidden(batch_size)

      # set accumulated gradients to zero
      net.zero_grad()
      
      # get the output from the model
      output, h = net(inputs, h)
      
      # calculate the loss and perform backprop
      loss = criterion(output, targets.view(-1))
      loss.backward()
      
      opt.step()
      
      if counter % print_every == 0:
        # Get validation loss
        
        val_losses = []

        net.eval()
        for x, y in get_batches(x_val_int, y_val_int, batch_size):
            
          x, y = torch.from_numpy(x), torch.from_numpy(y)
          
          val_h = net.init_hidden(batch_size)

          inputs, targets = x, y
          if(torch.cuda.is_available()):
            inputs, targets = inputs.cuda(), targets.cuda()

          output, val_h = net(inputs, val_h)

          val_loss = criterion(output, targets.view(-1))
          val_losses.append(val_loss.item())

        #save the best model
        if np.mean(val_losses) < best_valid_loss:
          best_valid_loss = np.mean(val_losses)
          torch.save(net.state_dict(), 'saved_weights.pt')

        net.train()

      
        print("Epoch: {}/{}...".format(e+1, epochs),
              "Step: {}...".format(counter),
              "Loss: {:.4f}...".format(loss.item()),
              "ppl: {:.4f} ".format(np.exp(np.mean(val_losses))),
              "Val Loss: {:.4f}".format(np.mean(val_losses)))

# %%
# specify batch size
batch_size = 64

# train the model
train(net, batch_size = batch_size, epochs=10)
# Out:
# Epoch: 1/10... Step: 32... Loss: 6.4961... ppl: 457.2359  Val Loss: 6.1252
# Epoch: 1/10... Step: 64... Loss: 5.1603... ppl: 310.5967  Val Loss: 5.7385
# Epoch: 1/10... Step: 96... Loss: 5.4773... ppl: 263.1113  Val Loss: 5.5726
# Epoch: 1/10... Step: 128... Loss: 5.4767... ppl: 219.8393  Val Loss: 5.3929
# Epoch: 10/10... Step: 7232... Loss: 1.7629... ppl: 88.3907  Val Loss: 4.4818
# Epoch: 10/10... Step: 7264... Loss: 1.8031... ppl: 90.4427  Val Loss: 4.5047
# Epoch: 10/10... Step: 7296... Loss: 1.6896... ppl: 92.0592  Val Loss: 4.5224
# Epoch: 10/10... Step: 7328... Loss: 2.0034... ppl: 89.6329  Val Loss: 4.4957
# Epoch: 10/10... Step: 7360... Loss: 2.1051... ppl: 90.9481  Val Loss: 4.5103
# Epoch: 10/10... Step: 7392... Loss: 1.8888... ppl: 91.1654  Val Loss: 4.5127
# Epoch: 10/10... Step: 7424... Loss: 1.9523... ppl: 90.3564  Val Loss: 4.5038
# Epoch: 10/10... Step: 7456... Loss: 1.4268... ppl: 89.2147  Val Loss: 4.4910
# Epoch: 10/10... Step: 7488... Loss: 1.7498... ppl: 91.4977  Val Loss: 4.5163
# Epoch: 10/10... Step: 7520... Loss: 1.4427... ppl: 93.1446  Val Loss: 4.5342
# Epoch: 10/10... Step: 7552... Loss: 1.7246... ppl: 93.4413  Val Loss: 4.5373
# Epoch: 10/10... Step: 7584... Loss: 1.8023... ppl: 93.1198  Val Loss: 4.5339
# Epoch: 10/10... Step: 7616... Loss: 2.0458... ppl: 99.3494  Val Loss: 4.5986
# Epoch: 10/10... Step: 7648... Loss: 1.6696... ppl: 94.0520  Val Loss: 4.5438
# Epoch: 10/10... Step: 7680... Loss: 2.2013... ppl: 96.6813  Val Loss: 4.5714
# Epoch: 10/10... Step: 7712... Loss: 1.7530... ppl: 93.0894  Val Loss: 4.5336
# Epoch: 10/10... Step: 7744... Loss: 1.5859... ppl: 94.6792  Val Loss: 4.5505
# Epoch: 10/10... Step: 7776... Loss: 1.6663... ppl: 94.8563  Val Loss: 4.5524
# Epoch: 10/10... Step: 7808... Loss: 2.3118... ppl: 96.7414  Val Loss: 4.5720

# %%
#load weights of best model
path = 'saved_weights.pt'
net.load_state_dict(torch.load(path))
# Out:
# <All keys matched successfully>

# %%
# function to generate one token
def predict(net, tkn, h=None):
         
  # tensor inputs
  x = np.array([[token2int[tkn]]])
  inputs = torch.from_numpy(x)
  
  if(torch.cuda.is_available()):
      inputs = inputs.cuda()

  # get the output of the model
  out, h = net(inputs, h)

  # get the token probabilities
  p = F.softmax(out, dim=1).data

  if(torch.cuda.is_available()):
      p = p.cpu()

  p = p.numpy()
  sampled_token_index = np.argmax(p, axis = 1)[0]
  
  # return the encoded value of the predicted char and the hidden state
  return int2token[sampled_token_index], h

# %%
# function to fetch generated sequence
def sample(net, size = 2, seed_text='it is'):
        
    if(torch.cuda.is_available()):
        net.cuda()
    
    net.eval()

    # batch size is 1
    h = net.init_hidden(1)

    toks = seed_text.split()

    # predict next token
    for t in toks:
      token, h = predict(net, t, h)
    
    toks.append(token)

    # predict subsequent tokens
    for i in range(size-1):
        token, h = predict(net, toks[-1], h)
        toks.append(token)

    return ' '.join(toks)

# %%
# seed texts
seeds = ["i want to",
         "how about a cup",
         "i don't want",
         "can you send",
         "my car"]

# number of tokens to generate
num_toks = 6

# text generation
for s in seeds:
  # get generated text from the model
  text_gen = sample(net, num_toks, seed_text=s)
  # print the result
  print("seed text:", s, ">> output:",text_gen)
  print("\n")
# Out:
# seed text: i want to >> output: i want to order a pi<unk><unk>a from pi<unk><unk>a hut
#
#
# seed text: how about a cup >> output: how about a cup and i don<unk>t want to be
#
#
# seed text: i don't want >> output: i don't want to be able to put in
#
#
# seed text: can you send >> output: can you send me a large pepperoni and ham
#
#
# seed text: my car >> output: my car and i don<unk>t want to be
